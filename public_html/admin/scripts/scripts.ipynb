# %% [markdown]
# # scripts
# The static files in prod is unchangeable by git pushes and pulls. they are in .gitignore
#
# In order to keep the development version in sync with the live site the static pages in prod need to be copied to dev. And then operated on.
#
# But what about resources?
# * leave audio, other print alone
# * leave songs alone too. /songs will be where any new links for a song go, but that change will be done from the admin panel running on prod site. It can be tested in dev.
