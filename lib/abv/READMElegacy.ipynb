# %% [markdown]
# # legacy system

# %%
# restart kernel then run this cell
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

# %% [markdown]
# ## sync with legacy site
# ### each sync with function

# %% [markdown]
# #### abv.download_file

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"
remote_dir ="public_html/"
filename="music-complete.html"
print("Downloading legacy HTML...")
abv.download_file(directory, remote_dir, filename)
with open(directory+"steps.json", "w") as f:
    f.write("[]")
abv.add_step(filename, directory)
# Out:
# ...
# ✓ music-complete.html downloaded to ../../process/music-complete.html
# - https://tryit.parleyvale.com/abv/process/music-complete.html

# %% [markdown]
# #### abv.preprocess_and_save(directory, filename)

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"
filename="music-complete.html"

processed_file_name = abv.preprocess_and_save(directory, filename)
print(f"processing complete and in {processed_file_name}.")
abv.add_step(processed_file_name, directory)
# Out:
# ../../process/music-complete.html
# Pre-processing complete.
# processing complete and in processed.html.
# - https://tryit.parleyvale.com/abv/process/music-complete.html
# - https://tryit.parleyvale.com/abv/process/processed.html

# %% [markdown]
# #### abv.split_to_songlist_and_header

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

processed_file_name = "processed.html"
abv.split_to_songlist_and_header(directory,processed_file_name)
abv.add_step("songlist.html", directory)
# Out:
# Pre-processing complete.
# HTML split into header and songlist.
# songlist.html and header.html created.
# Markdown conversion complete.
# Markdown file written to ../../process/songlist.md
# - https://tryit.parleyvale.com/abv/process/music-complete.html
# - https://tryit.parleyvale.com/abv/process/processed.html
# - https://tryit.parleyvale.com/abv/process/songlist.html

# %% [markdown]
# ### maybe tghis is redundant

# %%
# import abv
# from importlib import reload
# reload(abv)
# from bs4 import BeautifulSoup

# directory = "../../process/"

# processed_file_name = "processed.html"
# filepath = directory + processed_file_name
# with open(filepath, "r", encoding="utf-8") as f:
#     processed_text = f.read()
# header, songlist = abv.split_html(processed_text)
# songlist = songlist.replace('<p>', '').replace('</p>', '')
# soup = BeautifulSoup(songlist, "html.parser")
# songlist_txt = soup.prettify()
# with open(directory + "songlist.html", "w", encoding="utf-8") as f:
#     f.write(songlist_txt)
# print("Songlist saved to songlist.html")

# md_text = abv.create_songlist_md(soup)
# print("md_text created")

# with open(directory + "songlist.md", "w", encoding="utf-8") as f:
#     f.write(md_text)
# print("Songlist markdown saved to songlist.md")
# Out:
# HTML split into header and songlist.
# Songlist saved to songlist.html
# md_text created
# Songlist markdown saved to songlist.md

# %% [markdown]
# #### recreate_song_db

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

filepath = directory+"songlist.md"
with open(filepath, "r", encoding="utf-8") as f:
    md_list = f.read()
abv.recreate_song_db(directory, md_list)
# Out:
# ../../process/songs.db database recreated from markdown list.

# %% [markdown]
# #### reset_current()

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

abv.reset_current(directory, "currentSongs.json")
abv.add_step("",directory,"https://tryit.parleyvale.com/abv/app")
# Out:
# ../../process/currentSongs.json
# ['A Shtik fun Harts', 'Im Ein Ani Li', 'Kholemen Khaloymes', "Lo Yare'u / V'chit'tu", 'Lomir Zingen Dos Naye Lid', 'Volt Ikh Gehat Koyekh', 'Vortsl un Fligl', 'Zaman As-salam']
# Current songs reset from JSON file.
# - https://tryit.parleyvale.com/abv/process/music-complete.html
# - https://tryit.parleyvale.com/abv/process/processed.html
# - https://tryit.parleyvale.com/abv/process/songlist.html
# - https://tryit.parleyvale.com/abv/app//
# - https://tryit.parleyvale.com/abv/app/

# %% [markdown]
# ### all sync with functions

# %%
import abv
from importlib import reload
reload(abv)
directory = "../../process/"
# Download legacy music-complete.html
remote_dir ="public_html/"
filename="music-complete.html"
print("Downloading legacy HTML...")
abv.download_file(directory, remote_dir, filename)
with open(directory+"steps.json", "w") as f:
    f.write("[]")
abv.add_step(filename, directory)
## pre-process and save
processed_file_name = abv.preprocess_and_save(directory, filename)
print(f"processing complete and in {processed_file_name}.")
abv.add_step(processed_file_name, directory) 
## split to songlist and header
songlist_md_text = abv.split_to_songlist_and_header(directory,processed_file_name)
print("HTML split into header.html and songlist.md_html")
abv.add_step("songlist.html", directory)
# recreate song database from songlist_md_text
abv.recreate_song_db(directory, songlist_md_text)
print("Songs database recreated from songlist_md_text")
# reset_current from currentSongs.json
abv.reset_current(directory, "currentSongs.json")
print("Current songs reset from currentSongs.json")
abv.add_step("",directory,"https://tryit.parleyvale.com/abv/app")
# Out:
# ...
# ✓ music-complete.html downloaded to ../../process/music-complete.html
# - https://tryit.parleyvale.com/abv/process/music-complete.html
# ../../process/music-complete.html
# Pre-processing complete.
# processing complete and in processed.html.
# - https://tryit.parleyvale.com/abv/process/music-complete.html
# - https://tryit.parleyvale.com/abv/process/processed.html
# Pre-processing complete.
# HTML split into header and songlist.
# songlist.html and header.html created.
# Markdown conversion complete.
# Markdown file written to ../../process/songlist.md
# HTML split into header.html and songlist.md_html
# - https://tryit.parleyvale.com/abv/process/music-complete.html
# - https://tryit.parleyvale.com/abv/process/processed.html
# - https://tryit.parleyvale.com/abv/process/songlist.html
# ../../process/songs.db database recreated from markdown list.
# Songs database recreated from songlist_md_text
# ../../process/currentSongs.json
# ...

# %% [markdown]
# # sync back

# %% [markdown]
# ## resource upload
# This is a test suite for code run when `SyncBacktoLegacy` btn is pressed. This is the part of that code that only runs if there are resource files to upload

# %% [markdown]
# ### what's in resource list

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"
file_paths =abv.open_resource_list(directory)
print(file_paths)
for path in file_paths:
    print(path)
# Out:
# []

# %% [markdown]
# ### upload from resource_list
# if there is anything there

# %%
# here is the code to upload files to legacy server

for file_path in file_paths:
    print(f"  - Queuing: {file_path}")
rl = abv.open_resource_list(directory)# ../process/
print(rl)
message = abv.upload_abv("../../", rl)
print(message)
print("uploaded to legacy from resource_list.json")
# abv.delete_resource_list(directory)
# print("deleted to [], resource_list.json when done uploading")
# Out:
#   - Queuing: resources/audio/zztes_song/Lo_Yare_u_V_chitetu_full_from_10_19_rehearsal.m4a
#   - Queuing: resources/audio/zztes_song/LoYareu_alt.mp3
# ['resources/audio/zztes_song/Lo_Yare_u_V_chitetu_full_from_10_19_rehearsal.m4a', 'resources/audio/zztes_song/LoYareu_alt.mp3']
# Uploading ../../resources/audio/zztes_song/Lo_Yare_u_V_chitetu_full_from_10_19_rehearsal.m4a to resources/audio/zztes_song/Lo_Yare_u_V_chitetu_full_from_10_19_rehearsal.m4a...
# Created remote directory: resources/audio/zztes_song
# ✓ ../../resources/audio/zztes_song/Lo_Yare_u_V_chitetu_full_from_10_19_rehearsal.m4a uploaded to resources/audio/zztes_song/Lo_Yare_u_V_chitetu_full_from_10_19_rehearsal.m4a
# Uploading ../../resources/audio/zztes_song/LoYareu_alt.mp3 to resources/audio/zztes_song/LoYareu_alt.mp3...
# ✓ ../../resources/audio/zztes_song/LoYareu_alt.mp3 uploaded to resources/audio/zztes_song/LoYareu_alt.mp3
# None
# uploaded to legacy from resource_list.json

# %% [markdown]
# ### delete resource_list.json to []

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

message = abv.delete_resource_list(directory)
print(message)
# Out:
# resource_list.json reset to []

# %% [markdown]
# ## generating music-complete.html from songs.db

# %% [markdown]
# ### update current_songs.json

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"
with open(directory+"bsteps.json", "w") as f:
    f.write("[]")

message = abv.update_current(directory,"currentSongs.json")
print(message)

# %% [markdown]
# ### create_mdlist_from_db(directory)

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

message = abv.create_mdlist_from_db(directory)
print(message)
# Out:
# ✓ Created ../../process/mdList_from_songs.md with 122 songs

# %% [markdown]
# ### md_to_html

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"
md_file = "mdList_from_songs.md"
html_file = "mdList_from_songs.html" 
message = abv.md_to_html(directory, md_file, html_file)
print(message)
url = "https://tryit.parleyvale.com/abv/process/" + html_file

print(f"Access it at: {url}")
# Out:
# Converted ../../process/mdList_from_songs.md to ../../process/mdList_from_songs.html
#
# Access it at: https://tryit.parleyvale.com/abv/process/mdList_from_songs.html

# %% [markdown]
# ### recombine_html

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

header_file = "header.html"
body_file = "mdList_from_songs.html"
footer_file = "footer.html"
output_file = "music-complete-updated.html"
message = abv.recombine_html(directory,header_file, body_file, footer_file, output_file)
print(message)


url = "http://localhost/abv/process/" + output_file

print(f"Access it at: {url}")
# Out:
# Recombined HTML written to music-complete-updated.html
#
# Access it at: http://localhost/abv/process/music-complete-updated.html

# %%
localhost_base = "http://localhost:8000/abv/process/"
urls= []
urls.append(localhost_base + "header.html")
urls.append(localhost_base + "footer.html")
urls.append(localhost_base + "mdList_from_songs.html")
urls.append(localhost_base + "music-complete-updated.html")
urls.append(localhost_base + "music-current-updated.html")

for url in urls:
    print(f"access it at: {url}")
# Out:
# access it at: http://localhost:8000/abv/process/header.html
# access it at: http://localhost:8000/abv/process/footer.html
# access it at: http://localhost:8000/abv/process/mdList_from_songs.html
# access it at: http://localhost:8000/abv/process/music-complete-updated.html
# access it at: http://localhost:8000/abv/process/music-current-updated.html

# %% [markdown]
# ### copy from to music-complete.html

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

updated_file = "music-complete-updated.html"
replaced_file = "music-complete.html"
message = abv.copy_from_to(directory,updated_file, replaced_file)
print(message)
url = "https://tryit.parleyvale.com/abv/process/" + replaced_file

print(f"Access it at: {url}")
# Out:
# Copied from ../../process/music-complete-updated.html to ../../process/music-complete.html
#
# Access it at: https://tryit.parleyvale.com/abv/process/music-complete.html

# %% [markdown]
# ### rename remote file to backup

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"
 
message =abv.backup_remote_file(directory, "music-complete.html")
print(message)
url = "https://abvchorus.org/" + "music-complete_backup.html"
print(f"Access it at: {url}")
# Out:
# ftp.cwd(): /public_html
# Successfully renamed 'music-complete.html' to 'music-complete_backup.html'
#
# Access it at: https://abvchorus.org/music-complete_backup.html

# %% [markdown]
# ### upload music-complete.html

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

message = abv.upload_abv(directory,["music-complete.html"])
print(message)
url = "https://abvchorus.org/" + "music-complete.html"
print(f"Access it at: {url}")
# Out:
# Uploading ../../process/music-complete.html to music-complete.html...
#
# Access it at: https://abvchorus.org/music-complete.html

# %% [markdown]
# ### create_current_mdlist_from_db(directory)

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

message = abv.create_current_mdlist_from_db(directory)
print(message)
# Out:
# ✓ Created ../../process/current_mdlist.md with 8 current songs
# ../../process/current_mdlist.md

# %% [markdown]
# ### current_mdList to html

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

md_file = "current_mdlist.md"
html_file = "current_mdlist.html" 
message = abv.md_to_html(directory, md_file, html_file)
print(message)
url = "https://tryit.parleyvale.com/abv/process/" + html_file
print(f"Access it at: {url}")
# Out:
# Converted ../../process/current_mdlist.md to ../../process/current_mdlist.html
#
# Access it at: https://tryit.parleyvale.com/abv/process/current_mdlist.html

# %% [markdown]
# ### recombine current

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

header_file = "current_head.html"
body_file = "current_mdlist.html"
footer_file = "footer.html"
output_file = "music-current-updated.html"
message = abv.recombine_html(directory,header_file, body_file, footer_file, output_file)
print(message)
url = "https://tryit.parleyvale.com/abv/process/" + output_file
print(f"Access it at: {url}")
# Out:
# Recombined HTML written to music-current-updated.html
#
# Access it at: https://tryit.parleyvale.com/abv/process/music-current-updated.html

# %% [markdown]
# ### copy from to music-curretnt.html

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

updated_file = "music-current-updated.html"
replaced_file = "music-current.html"
message = abv.copy_from_to(directory,updated_file, replaced_file)
print(message)
url = "https://tryit.parleyvale.com/abv/process/" + replaced_file
print(f"Access it at: {url}")
# Out:
# Copied from ../../process/music-current-updated.html to ../../process/music-current.html
#
# Access it at: https://tryit.parleyvale.com/abv/process/music-current.html

# %% [markdown]
# ### backup remote music-currrent.html

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

message = abv.backup_remote_file(directory, "music-current.html")
print(message)
url = "https://abvchorus.org/" + "music-current_backup.html"
print(f"Access it at: {url}")
# Out:
# ftp.cwd(): /public_html
# Successfully renamed 'music-current.html' to 'music-current_backup.html'
#
# Access it at: https://abvchorus.org/music-current_backup.html

# %% [markdown]
# ### upload music-current.html

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../process/"

message = abv.upload_abv(directory,["music-current.html"])
print(message)
url = "https://abvchorus.org/" + "music-current.html"
print(f"Access it at: {url}")
# Out:
# Uploading ../../process/music-current.html to music-current.html...
#
# Access it at: https://abvchorus.org/music-current.html

# %% [markdown]
# ### all together - song.db to legacy

# %%
directory = "../../process/"

import abv
from importlib import reload
reload(abv)

message = abv.update_current(directory,"currentSongs.json")
print(message)
message = abv.create_mdlist_from_db(directory)
print(message)
md_file = "mdList_from_songs.md"
html_file = "mdList_from_songs.html" 
message = abv.md_to_html(directory, md_file, html_file)
print(message)
header_file = "header.html"
footer_file = "footer.html"
output_file = "music-complete-updated.html"
message = abv.recombine_html(directory,header_file, html_file, footer_file, output_file)
print(message)
updated_file = "music-complete-updated.html"
replaced_file = "music-complete.html"
message = abv.copy_from_to(directory,updated_file, replaced_file)
print(message)
message =abv.backup_remote_file(directory, "music-complete.html")
print(message)
message = abv.upload_abv(directory,["music-complete.html"])
print(message)
message = abv.create_current_mdlist_from_db(directory)
print(message)
md_file = "current_mdlist.md"
html_file = "current_mdlist.html" 
message = abv.md_to_html(directory, md_file, html_file)
print(message)
header_file = "current_head.html"
body_file = "current_mdlist.html"
footer_file = "footer.html"
output_file = "music-current-updated.html"
message = abv.recombine_html(directory,header_file, body_file, footer_file, output_file)
print(message)
updated_file = "music-current-updated.html"
replaced_file = "music-current.html"
message = abv.copy_from_to(directory,updated_file, replaced_file)
print(message)
message = abv.backup_remote_file(directory, "music-current.html")
print(message)
message = abv.upload_abv(directory,["music-current.html"])
print(message)
# Out:
# ✅ Exported 8 songs as simple array to ../../process/currentSongs.json
# song_names: ['A Shtik fun Harts', 'Im Ein Ani Li', 'Kholemen Khaloymes', "Lo Yare'u / V'chit'tu", 'Lomir Zingen Dos Naye Lid', 'Volt Ikh Gehat Koyekh', 'Vortsl un Fligl', 'Zaman As-salam']
#
# ✓ Created ../../process/mdList_from_songs.md with 122 songs
#
# Converted ../../process/mdList_from_songs.md to ../../process/mdList_from_songs.html
#
# Recombined HTML written to music-complete-updated.html
#
# Copied from ../../process/music-complete-updated.html to ../../process/music-complete.html
#
# ftp.cwd(): /public_html
# Successfully renamed 'music-complete.html' to 'music-complete_backup.html'
#
# Uploading ../../process/music-complete.html to music-complete.html...
#
# ✓ Created ../../process/current_mdlist.md with 8 current songs
# ../../process/current_mdlist.md
# Converted ../../process/current_mdlist.md to ../../process/current_mdlist.html
# ...

# %% [markdown]
# # other

# %% [markdown]
# ### manually upload resources

# %%
import abv
from importlib import reload
reload(abv)

directory = "../../"

abv.upload_abv(directory,["resources/audio/zaman/Zaman_Alsalam_Guitar_Demo.m4a","resources/print/Zaman_Al_Salam_Yair_Dalal_Lyrics.pdf"])
# Out:
# Uploading ../../resources/audio/zaman/Zaman_Alsalam_Guitar_Demo.m4a to resources/audio/zaman/Zaman_Alsalam_Guitar_Demo.m4a...
# ✓ ../../resources/audio/zaman/Zaman_Alsalam_Guitar_Demo.m4a uploaded to resources/audio/zaman/Zaman_Alsalam_Guitar_Demo.m4a
# Uploading ../../resources/print/Zaman_Al_Salam_Yair_Dalal_Lyrics.pdf to resources/print/Zaman_Al_Salam_Yair_Dalal_Lyrics.pdf...
# ✓ ../../resources/print/Zaman_Al_Salam_Yair_Dalal_Lyrics.pdf uploaded to resources/print/Zaman_Al_Salam_Yair_Dalal_Lyrics.pdf
# All files uploaded successfully!

# %% [markdown]
# ## functions extract clean text
# ### test code

# %%
md_text = """
- Arise, Arise  
  -  [Sheet music (updated March 25 2020)](resources/print/Arise%20Arise%20Mar2020v2.pdf)  
  - Audio files  
    -  [SATB](resources/audio/arise_arise/Arise%20SATB%2003_25_20.mp3) (all parts; sung by Linda G. and Gabrielle) 
    -  [Soprano](resources/audio/arise_arise/Arise_Arise_sop.m4a)  
    -  [Alto](resources/audio/arise_arise/Arise_Arise_alto.mp3)  
    - Tenor: [Listen and repeat](resources/audio/arise_arise/Arise%20tenor%20drill.mp3) ; [all the way through](resources/audio/arise_arise/Arise%20tenor.mp3)  
    -  [Bass](resources/audio/arise_arise/Arise%20Arise%20Bass.mp3)  
"""

def find_zero_level_lines(md_text):
    lines = md_text.strip().split('\n')
    zero_level_lines = [line for line in lines if line.startswith('- ')]
    nodash_lines = [line[2:] for line in zero_level_lines]
    nd_strip_lines = [line.strip() for line in nodash_lines]
    return nd_strip_lines

def clean_txt_or_fname(original_filename):
    #"""Clean filename while preserving extension - ABV style"""
    original_filename = original_filename.strip()
    if '.' in original_filename:
        name, ext = original_filename.rsplit('.', 1)
        # Replace all non-alphanumeric characters with underscores in name part
        cleaned_name = ''.join(c if c.isalnum() else '_' for c in name)
        return f"{cleaned_name}.{ext}"
    else:
        # No extension, clean the whole filename
        return ''.join(c if c.isalnum() else '_' for c in original_filename)

def make_dir_from_0level_line(md_text):
    zlines = find_zero_level_lines(md_text)
    clean_lines = [clean_txt_or_fname(line) for line in zlines]
    return [line.lower() for line in clean_lines]

# %% [markdown]
# ### find_zero_level_lines(), abv.clean_txt_or_fname(),abv.make_dir_from_0level_line()

# %%
import abv
from importlib import reload
reload(abv)
md_text = """
- Arise, Arise (2025) 
  -  [Sheet music (updated March 25 2020)](resources/print/Arise%20Arise%20Mar2020v2.pdf)  
  - Audio files  
    -  [SATB](resources/audio/arise_arise/Arise%20SATB%2003_25_20.mp3) (all parts; sung by Linda G. and Gabrielle) 
    -  [Soprano](resources/audio/arise_arise/Arise_Arise_sop.m4a)  
    -  [Alto](resources/audio/arise_arise/Arise_Arise_alto.mp3)  
    - Tenor: [Listen and repeat](resources/audio/arise_arise/Arise%20tenor%20drill.mp3) ; [all the way through](resources/audio/arise_arise/Arise%20tenor.mp3)  
    -  [Bass](resources/audio/arise_arise/Arise%20Arise%20Bass.mp3)  
"""

zlines = abv.find_zero_level_lines(md_text)
print(zlines)

clean = abv.clean_txt_or_fname(zlines[0])
print (clean)

dirs = abv.make_dir_from_0level_lines(md_text)[0]
print(dirs)
# Out:
# ['Arise, Arise (2025)']
# Arise__Arise__2025_
# arise__arise

# %%
import abv
from importlib import reload
reload(abv)

ftext ="""
resources/audio/Arbeter%20Froyen/Arbeter%20Froyen%20Yiddish%20pronunciation%20drill.mp3
"""
cleaned = abv.clean_txt_or_fname(ftext)
print(cleaned)
# Out:
# resources_audio_Arbeter_Froyen_Arbeter_Froyen_Yiddish_pronunciation_drill.mp3
